# %% [markdown]
# ### NLP and MultinomialNB Model - Get query index by passing movit title

# %%
# From pevious pipeline we have created movie_user_rating_index.csv
# We will use that csv here to get index for movie title

# %%
import pandas as pd
import numpy as np
import nltk
from nltk.tokenize import word_tokenize
import pickle
nltk.download('stopwords')
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Jagadheeswar
# [nltk_data]     Reddy\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Load movie_user_rating_index.csv
movie_user_rating_index=pd.read_csv("movie_user_rating_index.csv",encoding='utf-8',compression='gzip') 
movie_user_rating_index
# Out:
#      index                           title
# 0        0            10 cloverfield lane
# 1        1                      10,000 bc
# 2        2               12 years a slave
# 3        3                      127 hours
# 4        4                       17 again
# ..     ...                             ...
# 455    455  you don't mess with the zohan
# 456    456     zack and miri make a porno
# 457    457               zero dark thirty
# 458    458                     zombieland
# 459    459                       zootopia
#
# [460 rows x 2 columns]

# %%
# By mistakenly model was trained with one NAN value with movie title
# Anyway no problem we will remove this NAN and train NLP model
# Check summary of null values
movie_user_rating_index.isnull().sum()
# Out:
# index    0
# title    0
# dtype: int64

# %%
# we have only one null value,just remove this
movie_user_rating_index.dropna(inplace=True)
movie_user_rating_index.isnull().sum()
# Out:
# index    0
# title    0
# dtype: int64

# %%
# check shape of movie_user_rating_index
movie_user_rating_index.shape
# Out:
# (460, 2)

# %%
#remove special characters 
movie_user_rating_index['clean_title'] = movie_user_rating_index['title'].str.replace("[^0-9a-zA-Z#]", " ")
#lowercase all characters
movie_user_rating_index['clean_title'] = movie_user_rating_index['clean_title'].fillna('').apply(lambda x: x.lower())
movie_user_rating_index
# Out:
#      index                           title                     clean_title
# 0        0            10 cloverfield lane             10 cloverfield lane
# 1        1                      10,000 bc                       10 000 bc
# 2        2               12 years a slave                12 years a slave
# 3        3                      127 hours                       127 hours
# 4        4                       17 again                        17 again
# ..     ...                             ...                             ...
# 455    455  you don't mess with the zohan   you don t mess with the zohan
# 456    456     zack and miri make a porno      zack and miri make a porno
# 457    457               zero dark thirty                zero dark thirty
# 458    458                     zombieland                      zombieland
# 459    459                       zootopia                        zootopia
#
# [460 rows x 3 columns]

# %%
len(movie_user_rating_index)
# Out:
# 460

# %%
# tokenization - get all words from all movie titles
tokenized_doc = movie_user_rating_index['clean_title'].fillna('').apply(lambda x: x.split())
# remove stop-words
tokenized_doc = tokenized_doc.apply(lambda x: [item for item in x if item not in stop_words])
# de-tokenization
detokenized_doc = []
 # start from 1 and ends with length + 1 as move removed NAN from title 
 # it supposed to be like for i in range(0,len(movie_user_rating_index)):
for i in range(0,len(movie_user_rating_index)):
        t = " ".join(tokenized_doc[i])
        detokenized_doc.append(t)
movie_user_rating_index['clean_title'] = detokenized_doc

# %%
len(tokenized_doc)
# Out:
# 460

# %%
movie_user_rating_index
# Out:
#      index                           title           clean_title
# 0        0            10 cloverfield lane    10 cloverfield lane
# 1        1                      10,000 bc              10 000 bc
# 2        2               12 years a slave         12 years slave
# 3        3                      127 hours              127 hours
# 4        4                       17 again                     17
# ..     ...                             ...                   ...
# 455    455  you don't mess with the zohan             mess zohan
# 456    456     zack and miri make a porno   zack miri make porno
# 457    457               zero dark thirty       zero dark thirty
# 458    458                     zombieland             zombieland
# 459    459                       zootopia               zootopia
#
# [460 rows x 3 columns]

# %% [markdown]
# #### Words frequency Visualization

# %%
# combine all movie titles into singel string with help of concat with space " "
title = movie_user_rating_index.clean_title.str.cat(sep=' ')
#function to split text into word
tokens = word_tokenize(title)
vocabulary = set(tokens)
print("Total tokens = {0}".format(len(tokens)))
frequency_dist = nltk.FreqDist(tokens)
sorted(frequency_dist,key=frequency_dist.__getitem__, reverse=True)
# Out:
# Total tokens = 966
# ['man',
#  '2',
#  'part',
#  'star',
#  'dark',
#  'time',
#  'dawn',
#  'captain',
#  'world',
#  'men',
#  'wars',
#  'rise',
#  'dragon',
#  'hunger',
#  'games',
#  'twilight',
#  'x',
#  'street',
#  'spider',
#  'avengers',
#  'war',
#  'battle',
#  'runner',
#  'america',
#  'fantastic',
#  'prince',
#  'knight',
#  'shadows',
#  'end',
#  'game',
#  'mr',
#  'get',
#  'green',
#  'guardians',
#  'hangover',
#  'harry',
#  'potter',
#  '1',
#  'hobbit',
#  'inside',
#  'iron',
#  '3',
#  'story',
#  'john',
#  'life',
#  'c',
#  'road',
#  'vs',
#  'moon',
#  'sherlock',
#  'trek',
#  'thor',
#  'saga',
#  '10',
#  'cloverfield',
#  '21',
#  'jump',
#  '50',
#  '9',
#  'amazing',
#  'american',
#  'age',
#  'job',
#  'kind',
#  'midnight',
#  'big',
#  'black',
#  'side',
#  'blue',
#  'book',
#  'bourne',
#  'legacy',
#  'first',
#  'winter',
#  'soldier',
#  'chronicles',
#  'narnia',
#  'aliens',
#  'high',
#  'love',
#  'date',
#  'night',
#  'planet',
#  'apes',
#  'day',
#  'despicable',
#  'doctor',
#  'horrible',
#  'hell',
#  'expendables',
#  'fury',
#  'ghost',
#  'girl',
#  'hotel',
#  'galaxy',
#  'ii',
#  'escape',
#  'deathly',
#  'hallows',
#  'train',
#  'kingdom',
#  'wick',
#  'two',
#  'kick',
#  'ass',
#  'secret',
#  'strings',
#  'kung',
#  'fu',
#  'panda',
#  'la',
#  'lincoln',
#  'louis',
#  'k',
#  'max',
#  'steel',
#  'maze',
#  'mission',
#  'impossible',
#  'rogue',
#  'monsters',
#  'three',
#  'days',
#  'see',
#  'guys',
#  'beyond',
#  'red',
#  'evil',
#  'seven',
#  'holmes',
#  'spy',
#  'new',
#  'taken',
#  'terminator',
#  'mockingjay',
#  'e',
#  'transformers',
#  'underworld',
#  'wall',
#  'wild',
#  'wolverine',
#  'lane',
#  '000',
#  'bc',
#  '12',
#  'years',
#  'slave',
#  '127',
#  'hours',
#  '17',
#  '2012',
#  '22',
#  '27',
#  'dresses',
#  'team',
#  'adjustment',
#  'bureau',
#  'adventureland',
#  'adventures',
#  'tintin',
#  'alice',
#  'wonderland',
#  'hustle',
#  'sniper',
#  'anchorman',
#  'legend',
#  'continues',
#  'angels',
#  'demons',
#  'ant',
#  'antichrist',
#  'argo',
#  'arrival',
#  'avatar',
#  'ultron',
#  'infinity',
#  'babadook',
#  'baby',
#  'driver',
#  'bad',
#  'teacher',
#  'bank',
#  'batman',
#  'v',
#  'superman',
#  'justice',
#  'los',
#  'angeles',
#  'rewind',
#  'hero',
#  '6',
#  'short',
#  'panther',
#  'swan',
#  'blade',
#  '2049',
#  'blind',
#  'jasmine',
#  'valentine',
#  'body',
#  'lies',
#  'bolt',
#  'eli',
#  'boyhood',
#  'brave',
#  'bridesmaids',
#  'bridge',
#  'spies',
#  'burn',
#  'reading',
#  'cabin',
#  'woods',
#  'civil',
#  'avenger',
#  'phillips',
#  'changeling',
#  'chappie',
#  'chronicle',
#  'caspian',
#  'voyage',
#  'treader',
#  'citizenfour',
#  'clash',
#  'titans',
#  'cloud',
#  'atlas',
#  'cloudy',
#  'chance',
#  'meatballs',
#  'coco',
#  'conjuring',
#  'contagion',
#  'coraline',
#  'cowboys',
#  'crank',
#  'voltage',
#  'crazy',
#  'stupid',
#  'creed',
#  'croods',
#  'curious',
#  'case',
#  'benjamin',
#  'button',
#  'dallas',
#  'buyers',
#  'club',
#  'rises',
#  'earth',
#  'stood',
#  'still',
#  'deadpool',
#  'death',
#  'race',
#  'definitely',
#  'maybe',
#  'descendants',
#  'dictator',
#  'district',
#  'divergent',
#  'django',
#  'unchained',
#  'strange',
#  'jon',
#  'doubt',
#  'dr',
#  'sing',
#  'along',
#  'blog',
#  'drag',
#  'dredd',
#  'drive',
#  'due',
#  'dunkirk',
#  'eagle',
#  'eye',
#  'easy',
#  'edge',
#  'tomorrow',
#  'education',
#  'elysium',
#  'watch',
#  'ender',
#  'equalizer',
#  'ex',
#  'machina',
#  'exit',
#  'gift',
#  'shop',
#  'beasts',
#  'find',
#  'fox',
#  'fighter',
#  'finding',
#  'dory',
#  'flight',
#  'focus',
#  'forgetting',
#  'sarah',
#  'marshall',
#  'friends',
#  'benefits',
#  'frost',
#  'nixon',
#  'frozen',
#  'furious',
#  '7',
#  'g',
#  'joe',
#  'cobra',
#  'gamer',
#  'greek',
#  'smart',
#  'writer',
#  'tattoo',
#  'godzilla',
#  'gone',
#  'gran',
#  'torino',
#  'grand',
#  'budapest',
#  'gravity',
#  'great',
#  'gatsby',
#  'hornet',
#  'lantern',
#  'zone',
#  'grey',
#  'grown',
#  'ups',
#  'hacksaw',
#  'ridge',
#  'hancock',
#  'iii',
#  'hanna',
#  'happening',
#  'harold',
#  'kumar',
#  'guantanamo',
#  'bay',
#  'half',
#  'blood',
#  'water',
#  'hellboy',
#  'golden',
#  'army',
#  'help',
#  'hidden',
#  'figures',
#  'unexpected',
#  'journey',
#  'desolation',
#  'smaug',
#  'bosses',
#  'horton',
#  'hears',
#  'hot',
#  'tub',
#  'machine',
#  'transylvania',
#  'hugo',
#  'hurt',
#  'locker',
#  'number',
#  'four',
#  'ice',
#  'dinosaurs',
#  'ides',
#  'march',
#  'imaginarium',
#  'parnassus',
#  'bruges',
#  'inception',
#  'incredible',
#  'hulk',
#  'indiana',
#  'jones',
#  'crystal',
#  'skull',
#  'inglourious',
#  'basterds',
#  'llewyn',
#  'davis',
#  'insidious',
#  'insurgent',
#  'interstellar',
#  'intouchables',
#  'invention',
#  'lying',
#  'invictus',
#  'ip',
#  'follows',
#  'funny',
#  'jack',
#  'reacher',
#  'jason',
#  'jiro',
#  'dreams',
#  'sushi',
#  'carter',
#  'chapter',
#  'julie',
#  'julia',
#  'jumper',
#  'jupiter',
#  'ascending',
#  'jurassic',
#  'karate',
#  'kid',
#  'kids',
#  'right',
#  'king',
#  'speech',
#  'kingsman',
#  'service',
#  'knowing',
#  'kubo',
#  'land',
#  'law',
#  'abiding',
#  'citizen',
#  'pi',
#  'limitless',
#  'lawyer',
#  'logan',
#  'lone',
#  'ranger',
#  'looper',
#  'hilarious',
#  'live',
#  'beacon',
#  'theater',
#  'lucy',
#  'machete',
#  'mad',
#  'madagascar',
#  'africa',
#  'maleficent',
#  'mamma',
#  'mia',
#  'wire',
#  'manchester',
#  'sea',
#  'marley',
#  'mary',
#  'master',
#  'scorch',
#  'trials',
#  'mechanic',
#  'megamind',
#  'melancholia',
#  'stare',
#  'goats',
#  'paris',
#  'milk',
#  'minions',
#  'protocol',
#  'nation',
#  'mis',
#  'rables',
#  'les',
#  'moana',
#  'moneyball',
#  'university',
#  'moonlight',
#  'moonrise',
#  'nobody',
#  'mud',
#  'mummy',
#  'tomb',
#  'emperor',
#  'neighbors',
#  'never',
#  'let',
#  'go',
#  'next',
#  'nick',
#  'norah',
#  'infinite',
#  'playlist',
#  'museum',
#  'smithsonian',
#  'nightcrawler',
#  'attached',
#  'oblivion',
#  'pacific',
#  'rim',
#  'pandorum',
#  'paperman',
#  'paranormal',
#  'activity',
#  'passengers',
#  'paul',
#  'percy',
#  'jackson',
#  'olympians',
#  'lightning',
#  'thief',
#  'perks',
#  'wallflower',
#  'pineapple',
#  'express',
#  'pirate',
#  'radio',
#  'pirates',
#  'caribbean',
#  'stranger',
#  'tides',
#  'pitch',
#  'perfect',
#  'place',
#  'pines',
#  'predators',
#  'predestination',
#  'persia',
#  'sands',
#  'princess',
#  'frog',
#  'prisoners',
#  'prometheus',
#  'proposal',
#  'public',
#  'enemies',
#  'puss',
#  'boots',
#  'quantum',
#  'solace',
#  'rango',
#  'reader',
#  'real',
#  'resident',
#  'afterlife',
#  'revolutionary',
#  'riddick',
#  'rio',
#  'robin',
#  'hood',
#  'robocop',
#  'rocknrolla',
#  'one',
#  'role',
#  'models',
#  'room',
#  'rush',
#  'safety',
#  'guaranteed',
#  'salt',
#  'saving',
#  'banks',
#  'scott',
#  'pilgrim',
#  'walter',
#  'mitty',
#  'senna',
#  'serious',
#  'pounds',
#  'psychopaths',
#  'sex',
#  'city',
#  'abominable',
#  'bride',
#  'shutter',
#  'island',
#  'sicario',
#  'effects',
#  'silver',
#  'linings',
#  'playbook',
#  'single',
#  'skyfall',
#  'slumdog',
#  'millionaire',
#  'snow',
#  'white',
#  'huntsman',
#  'snowpiercer',
#  'social',
#  'network',
#  'sorcerer',
#  'apprentice',
#  'source',
#  'code',
#  'spectre',
#  'split',
#  'spotlight',
#  'darkness',
#  'episode',
#  'vii',
#  'force',
#  'awakens',
#  'clone',
#  'last',
#  'jedi',
#  'step',
#  'brothers',
#  'sucker',
#  'punch',
#  'suicide',
#  'squad',
#  'sully',
#  'super',
#  '8',
#  'surrogates',
#  'synecdoche',
#  'york',
#  'tangled',
#  'ted',
#  'genisys',
#  'salvation',
#  'accountant',
#  'artist',
#  'fault',
#  'stars',
#  'hateful',
#  'eight',
#  'five',
#  'armies',
#  'catching',
#  'fire',
#  'imitation',
#  'intern',
#  'interview',
#  'jungle',
#  'lego',
#  'movie',
#  'lobster',
#  'u',
#  'n',
#  'l',
#  'martian',
#  'nice',
#  'raid',
#  'redemption',
#  'revenant',
#  'theory',
#  'everything',
#  'ragnarok',
#  'billboards',
#  'outside',
#  'ebbing',
#  'missouri',
#  'traveler',
#  'wife',
#  'tinker',
#  'tailor',
#  'tomorrowland',
#  'total',
#  'recall',
#  'tourist',
#  'town',
#  'toy',
#  'transcendence',
#  'revenge',
#  'fallen',
#  'transporter',
#  'tree',
#  'tron',
#  'tropic',
#  'thunder',
#  'true',
#  'grit',
#  'tucker',
#  'dale',
#  'breaking',
#  'eclipse',
#  'ugly',
#  'truth',
#  'awakening',
#  'lycans',
#  'unknown',
#  'unstoppable',
#  'untitled',
#  'reboot',
#  'air',
#  'valkyrie',
#  'vantage',
#  'point',
#  'vicky',
#  'cristina',
#  'barcelona',
#  'wanted',
#  'warm',
#  'bodies',
#  'warrior',
#  'watchmen',
#  'need',
#  'talk',
#  'kevin',
#  'millers',
#  'happens',
#  'vegas',
#  'things',
#  'whiplash',
#  'tales',
#  'bone',
#  'wolf',
#  'wonder',
#  'woman',
#  'z',
#  'wreck',
#  'ralph',
#  'wrestler',
#  'origins',
#  'apocalypse',
#  'future',
#  'past',
#  'class',
#  'yes',
#  'mess',
#  'zohan',
#  'zack',
#  'miri',
#  'make',
#  'porno',
#  'zero',
#  'thirty',
#  'zombieland',
#  'zootopia']

# %%
from wordcloud import WordCloud
from matplotlib.pyplot import figure
import matplotlib.pyplot as plt
figure(num=None, figsize=(12, 10), dpi=80, facecolor='w', edgecolor='k')
wordcloud = WordCloud().generate_from_frequencies(frequency_dist)

plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %% [markdown]
# #### Create MultinomialNB model

# %%
# movie title is input and index is output
X_train = movie_user_rating_index.clean_title.values
y_train = movie_user_rating_index.index.values

# %%
# To train model, all data should be numbers
# X_train is list of title ie these words shoud be converted to numbers with help of bag of words or TFIDF
# Y_train is already numbers so we dont need to convert them
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer()
train_vectors = vectorizer.fit_transform(X_train)
print(train_vectors.shape)
# Out:
# (460, 701)

# %%
# create and train the model
from sklearn.naive_bayes import MultinomialNB
classifier = MultinomialNB().fit(train_vectors, y_train)

# %%
# Testig the model by passing some title and validate index like accuracy
X_test = movie_user_rating_index.loc[:20, 'title'].values
y_test = movie_user_rating_index.loc[:20, 'index'].values
test_vectors = vectorizer.transform(X_test)

# %%
# accuracy score 1.0 ie our model will predict correct index for movie title
from  sklearn.metrics  import accuracy_score
predicted = classifier.predict(test_vectors)
print(accuracy_score(y_test,predicted))
# Out:
# 0.9523809523809523

# %% [markdown]
# #### Manual Tesing

# %%
# display last records
movie_user_rating_index.tail(10)
# Out:
#      index                           title              clean_title
# 450    450       x-men origins: wolverine   x men origins wolverine
# 451    451              x-men: apocalypse          x men apocalypse
# 452    452     x-men: days of future past    x men days future past
# 453    453             x-men: first class         x men first class
# 454    454                        yes man                   yes man
# 455    455  you don't mess with the zohan                mess zohan
# 456    456     zack and miri make a porno      zack miri make porno
# 457    457               zero dark thirty          zero dark thirty
# 458    458                     zombieland                zombieland
# 459    459                       zootopia                  zootopia

# %%
# Pass movie name and check index predicted correctly or not
#name=" III Rambo"
#name="zero dark thirty"
#test_vector= vectorizer.transform([name])
#predicted = classifier.predict(test_vector)
#print("{0} : {1}".format(predicted[0], movie_user_rating_index.title[predicted[0]]))
# Out:
# 457 : zero dark thirty

# %%
# Load KNN model
model_knn = pickle.load( open( "collaborativeFiltering_model.pkl", "rb" ) )

# %%
# load movie_user_rating_index.csv
movie_features_index_df=pd.read_csv("movie_user_rating_index.csv",encoding ='utf-8',compression='gzip')

# %%
# Load pivot test table  - used 10 movies data for testing
movie_user_rating_pivottable=pd.read_csv("movie_user_rating_pivottable_test.csv",encoding ='utf-8',compression='gzip')

# %%
# Pass index and get similar movies
def getRecomendedMoviesByIndex(queryIndex,numOfMovies):
    distances, indices = model_knn.kneighbors(movie_user_rating_pivottable.iloc[queryIndex,:].values.reshape(1, -1), n_neighbors = numOfMovies)
    return distances,indices

# %%
# Pass movie name and get index
def getMovieIndex(name):
    name=name.strip().lower()
    test_vector= vectorizer.transform([name])
    predicted = classifier.predict(test_vector)
    print("{0} : {1}".format(predicted[0], movie_features_index_df.title[predicted[0]]))
    return predicted[0]

# %%
# Pass movie name and get similar movies
def recommendedMovies(name,numOfMovies=5):
    movieList=list()
    query_index=getMovieIndex(name)
    print(query_index)
    distances, indices =getRecomendedMoviesByIndex(query_index,numOfMovies)
    for i in range(0, len(distances.flatten())):
        movieList.append(movie_features_index_df.title[indices.flatten()[i]])
    return movieList

# %%
recommendedMovies("10 000 bc" ,5)
# Out:
# 1 : 10,000 bc
# 1
# ['10,000 bc ',
#  'jumper ',
#  'clash of the titans ',
#  'hancock ',
#  'transformers: revenge of the fallen ']

# %%
# save the MultinomialNB classifier model
fileName="collaborativeFiltering_NLP_model.pkl"
pickle.dump(classifier,open(fileName,'wb'))

# %%
# save the vectorizer classifier model
fileName="collaborativeFiltering_NLP_vectorizer.pkl"
pickle.dump(vectorizer, open(fileName, "wb"))

# %%
# dont need this csv file
# save trained vectorizer
#trained_vectorizer = movie_user_rating_index.clean_title.values
#trained_vectorizer_df = pd.DataFrame({'trained_vectorizer': trained_vectorizer})

#trained_vectorizer_df.to_csv('trained_vectorizer.csv', index=False,encoding='utf-8')
